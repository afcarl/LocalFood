# %%
import pandas as pd
import numpy as np

# %%
surplus = pd.read_csv('data/surplus.csv',usecols=[u'FIPS',  u'County Name',u'SURPLUS',
       u'COUNTY_x'])
distance_matrix = pd.read_csv('data/distance_matrix.csv')

# %%
surplus.columns
# Out:
# Index([u'FIPS', u'County Name', u'SURPLUS', u'COUNTY_x'], dtype='object')

# %%
surplus.head()
# Out:
#    FIPS County Name       SURPLUS  COUNTY_x
# 0  1001     Autauga -10340.555000      1001
# 1  1003     Baldwin -35859.112500      1003
# 2  1005     Barbour  -5737.651707      1005
# 3  1007        Bibb  -4458.137500      1007
# 4  1009      Blount  -3422.289054      1009

# %%
surplus['new_surplus'] = surplus.SURPLUS

# %%
distance_matrix = distance_matrix.set_index('county_A')[['county_B','distance']]

# %%
distance_matrix = distance_matrix[distance_matrix.distance != 0.0]

# %%
distance_matrix
# Out:
#              county_B    distance
# county_A
# Autauga       Baldwin  140.370274
# Autauga       Barbour   86.545903
# Autauga          Bibb   42.446217
# Autauga        Blount  100.213979
# Autauga       Bullock   62.169643
# Autauga        Butler   54.167414
# Autauga       Calhoun   97.999915
# Autauga      Chambers   77.224515
# Autauga      Cherokee  128.194864
# Autauga       Chilton   22.179545
# Autauga       Choctaw  101.226122
# Autauga        Clarke   91.425982
# Autauga          Clay   67.844735
# Autauga      Cleburne  101.706589
# Autauga        Coffee   87.206351
# Autauga       Colbert  163.948630
# Autauga       Conecuh   78.982843
# Autauga         Coosa   35.671540
# Autauga     Covington   89.741867
# Autauga      Crenshaw   58.714611
# Autauga       Cullman  110.806065
# Autauga          Dale   97.364412
# Autauga        Dallas   30.803426
# Autauga        DeKalb  141.183131
# Autauga        Elmore   29.191888
# Autauga      Escambia  102.062317
# ...

# %%
distance_matrix.ix['Autauga'].sort_values(by='distance')
# Out:
#                       county_B     distance
# county_A
# Autauga                Chilton    22.179545
# Autauga                Lowndes    26.035674
# Autauga                 Elmore    29.191888
# Autauga                 Dallas    30.803426
# Autauga             Montgomery    33.672555
# Autauga                  Coosa    35.671540
# Autauga                  Perry    38.925541
# Autauga                   Bibb    42.446217
# Autauga                 Shelby    50.375174
# Autauga             Tallapoosa    54.141268
# Autauga                 Butler    54.167414
# Autauga                 Wilcox    54.255829
# Autauga                  Macon    56.434428
# Autauga               Crenshaw    58.714611
# Autauga                   Hale    59.709979
# Autauga                Bullock    62.169643
# Autauga              Talladega    64.293852
# Autauga                   Pike    65.080173
# Autauga                   Clay    67.844735
# Autauga                Marengo    69.694819
# ...

# %%
for index,county in surplus.iterrows():
    deficit = surplus.SURPLUS[index]
    county_A = county['County Name']
    if deficit < 0.0:
        nearest_counties = distance_matrix.ix[county_A].sort_values(by='distance')
        for indexB,row in nearest_counties.iterrows():
            print(surplus[surplus['County Name']==row.county_B]['SURPLUS'])
            try: 
                vd = float(surplus[surplus['County Name']==row.county_B]['SURPLUS'])>0.
                
            except TypeError:
                vd = float(surplus[surplus['County Name']==row.county_B]['SURPLUS'][0])>0.
            except KeyError:
                vd = float(surplus[surplus['County Name']==row.county_B]['SURPLUS'])>0.
            if vd:
                print("Hello")
#            distance_matrix.ix[county_A].sort_values(by='distance')
#            # Update deficit and surplus on the data frame. This will make it dependent on the alphabet.
#            deficit -=
# Out:
# 10   -2921.605155
# Name: SURPLUS, dtype: float64
# 42      -2195.211707
# 478      2137.473792
# 1444   -10476.974896
# Name: SURPLUS, dtype: float64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-3c7af25c223f> in <module>()
#      10
#      11             except TypeError:
# ---> 12                 vd = float(surplus[surplus['County Name']==row.county_B]['SURPLUS'][0])>0.
#      13             except KeyError:
#      14                 vd = float(surplus[surplus['County Name']==row.county_B]['SURPLUS'])>0.
#
# /home/saf537/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in __getitem__(self, key)
#     558     def __getitem__(self, key):
#     559         try:
# --> 560             result = self.index.get_value(self, key)
#     561
#     562             if not lib.isscalar(result):
#
# ...

# %%
nearest_counties
# Out:
#              county_B     distance
# county_A
# Lee            Harlan    11.816550
# Lee            Owsley    11.985582
# Lee           Hancock    13.800834
# Lee            Estill    14.956154
# Lee             Wolfe    15.707405
# Lee           Chatham    16.492170
# Lee       St. Francis    16.563626
# Lee            Powell    17.070813
# Lee           Terrell    17.586117
# Lee         Dougherty    17.824953
# Lee            Sumter    18.137285
# Lee          Itawamba    18.328359
# Lee           Harnett    18.641132
# Lee            Sumter    18.823913
# Lee           Jackson    19.790082
# Lee              Ogle    20.521304
# Lee          Pontotoc    20.772671
# Lee             Clark    20.825083
# Lee           Hawkins    20.875052
# Lee        Darlington    20.974481
# Lee             Moore    21.008496
# Lee         Breathitt    21.629621
# Lee          Chambers    21.731702
# Lee           Kershaw    22.335738
# Lee         Charlotte    23.015041
# ...
