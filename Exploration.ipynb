# %%
import pandas as pd

# %%
dev_ing = pd.read_csv('./data/category_developing-country.csv')

# %%
dev_ing.head(20)
# Out:
#    category developing-country scores Unnamed: 1        Unnamed: 2  \
# 0                                 NaN        NaN               NaN
# 1                                 NaN        NaN               NaN
# 2                                 NaN        NaN               NaN
# 3                             Country       ISO3     Subcontinents
# 4                         Afghanistan        AFG     Southern Asia
# 5                             Albania        ALB   Southern Europe
# 6                             Algeria        DZA   Northern Africa
# 7                              Angola        AGO     Middle Africa
# 8                           Argentina        ARG  Southern America
# 9                             Armenia        ARM      Western Asia
# 10                         Azerbaijan        AZE      Western Asia
# 11                            Bahrain        BHR      Western Asia
# 12                         Bangladesh        BGD     Southern Asia
# ...

# %%
dev_ing.iloc[3]
# Out:
# category developing-country scores                                       Country
# Unnamed: 1                                                                  ISO3
# Unnamed: 2                                                         Subcontinents
# Unnamed: 3                                                                Groups
# Unnamed: 4                                                   Remote Country ISO3
# ERH                                                                        Needs
# ERH.1                                                                   Policies
# ERH.2                                                                  Resources
# ERH.3                                                             Access to Food
# ERH.4                                                               Malnutrition
# ERH.5                                              Agricultural Productivity Gap
# ERH.6                                                              Vulnerability
# ...
